# %% [markdown]
# <div align="center">
# <img align="center" src="https://stelar-project.eu/wp-content/uploads/2022/08/cropped-stelar-sq.png?raw=true" alt="pyJedAI" width="250"/>
#
# <strong>Deduplication Use Case</strong>
# </div>
# <div align="center">
# <img align="center" src="https://github.com/AI-team-UoA/.github/blob/main/AI_LOGO-1.png?raw=true" alt="pyJedAI" width="160"/>
# <img align="center" src="https://agroknow.com/wp-content/uploads/2020/04/logo_agroknow_sm.png?raw=true" alt="pyJedAI" width="160"/>
# <img align="center" src="https://github.com/Nikoletos-K/pyJedAI/blob/main/docs/img/pyjedai.logo.drawio.png?raw=true" alt="pyJedAI" width="250"/>
# </div>
#
# ---

# %% [markdown]
# # Initialize data and pyJedAI
# Execute cell to initialize application and read the data.

# %%
import plotly.express as px
import os
import pandas as pd

# Do this BEFORE importing the package
import tqdm
import tqdm.notebook

# Replace all tqdm with notebook version
tqdm.tqdm = tqdm.notebook.tqdm
tqdm.trange = tqdm.notebook.trange

# Now import your package

# %pip install pyjedai

# from google.colab import drive
# drive.mount(r'/content/drive/')

# incidents = os.path.abspath(r"content/drive/My Drive/Projects/STELAR/data/Agroknow/incidents.csv")

d1 = pd.read_csv("incidents.csv", sep=',', na_filter=False)


import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# LIBS
import sys
import networkx
from networkx import draw, Graph
import pyjedai
from pyjedai.datamodel import Data
from pyjedai.utils import (
    text_cleaning_method,
    print_clusters,
    print_blocks,
    print_candidate_pairs
)
from pyjedai.evaluation import Evaluation
# Out:
# Requirement already satisfied: pyjedai in ./.conda/envs/exp/lib/python3.9/site-packages (0.3.3)
# Requirement already satisfied: matplotlib in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (3.9.4)
# Requirement already satisfied: networkx in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (3.2.1)
# Requirement already satisfied: nltk in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (3.9.1)
# Requirement already satisfied: numpy<3.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (1.26.4)
# Requirement already satisfied: pandas in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (2.1.4)
# Requirement already satisfied: scipy in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (1.12.0)
# Requirement already satisfied: seaborn in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (0.13.2)
# Requirement already satisfied: tqdm in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (4.67.1)
# Requirement already satisfied: transformers in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (4.53.1)
# Requirement already satisfied: sentence-transformers in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (5.0.0)
# Requirement already satisfied: faiss-cpu in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (1.11.0)
# Requirement already satisfied: py-stringmatching in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (0.4.6)
# Requirement already satisfied: valentine in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (0.2.1)
# Requirement already satisfied: ordered-set in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (4.1.0)
# Requirement already satisfied: shapely in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (2.0.7)
# Requirement already satisfied: ollama in ./.conda/envs/exp/lib/python3.9/site-packages (from pyjedai) (0.5.1)
# Requirement already satisfied: packaging in ./.conda/envs/exp/lib/python3.9/site-packages (from faiss-cpu->pyjedai) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (1.4.7)
# Requirement already satisfied: pillow>=8 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from matplotlib->pyjedai) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->pyjedai) (3.23.0)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/exp/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->pyjedai) (1.17.0)
# Requirement already satisfied: click in ./.conda/envs/exp/lib/python3.9/site-packages (from nltk->pyjedai) (8.1.8)
# Requirement already satisfied: joblib in ./.conda/envs/exp/lib/python3.9/site-packages (from nltk->pyjedai) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in ./.conda/envs/exp/lib/python3.9/site-packages (from nltk->pyjedai) (2024.11.6)
# Requirement already satisfied: httpx>=0.27 in ./.conda/envs/exp/lib/python3.9/site-packages (from ollama->pyjedai) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in ./.conda/envs/exp/lib/python3.9/site-packages (from ollama->pyjedai) (2.11.7)
# Requirement already satisfied: anyio in ./.conda/envs/exp/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (4.9.0)
# Requirement already satisfied: certifi in ./.conda/envs/exp/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in ./.conda/envs/exp/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (1.0.9)
# Requirement already satisfied: idna in ./.conda/envs/exp/lib/python3.9/site-packages (from httpx>=0.27->ollama->pyjedai) (3.10)
# Requirement already satisfied: h11>=0.16 in ./.conda/envs/exp/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27->ollama->pyjedai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.conda/envs/exp/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./.conda/envs/exp/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from pydantic>=2.9->ollama->pyjedai) (0.4.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.conda/envs/exp/lib/python3.9/site-packages (from anyio->httpx>=0.27->ollama->pyjedai) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from anyio->httpx>=0.27->ollama->pyjedai) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from pandas->pyjedai) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from pandas->pyjedai) (2025.2)
# Requirement already satisfied: torch>=1.11.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from sentence-transformers->pyjedai) (2.7.1)
# Requirement already satisfied: scikit-learn in ./.conda/envs/exp/lib/python3.9/site-packages (from sentence-transformers->pyjedai) (1.6.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from sentence-transformers->pyjedai) (0.33.2)
# Requirement already satisfied: filelock in ./.conda/envs/exp/lib/python3.9/site-packages (from transformers->pyjedai) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from transformers->pyjedai) (6.0.2)
# Requirement already satisfied: requests in ./.conda/envs/exp/lib/python3.9/site-packages (from transformers->pyjedai) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in ./.conda/envs/exp/lib/python3.9/site-packages (from transformers->pyjedai) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in ./.conda/envs/exp/lib/python3.9/site-packages (from transformers->pyjedai) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->pyjedai) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in ./.conda/envs/exp/lib/python3.9/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->pyjedai) (1.1.5)
# Requirement already satisfied: sympy>=1.13.3 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (1.14.0)
# Requirement already satisfied: jinja2 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers->pyjedai) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from triton==3.3.1->torch>=1.11.0->sentence-transformers->pyjedai) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers->pyjedai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers->pyjedai) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.conda/envs/exp/lib/python3.9/site-packages (from requests->transformers->pyjedai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.conda/envs/exp/lib/python3.9/site-packages (from requests->transformers->pyjedai) (2.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from scikit-learn->sentence-transformers->pyjedai) (3.6.0)
# Requirement already satisfied: anytree<3.0,>=2.9 in ./.conda/envs/exp/lib/python3.9/site-packages (from valentine->pyjedai) (2.13.0)
# Requirement already satisfied: chardet<6.0.0,>=5.2.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from valentine->pyjedai) (5.2.0)
# Requirement already satisfied: jellyfish<1.1,>=0.9 in ./.conda/envs/exp/lib/python3.9/site-packages (from valentine->pyjedai) (1.0.4)
# Requirement already satisfied: PuLP<3.0,>=2.5 in ./.conda/envs/exp/lib/python3.9/site-packages (from valentine->pyjedai) (2.9.0)
# Requirement already satisfied: pyemd<2.0,>=1.0.0 in ./.conda/envs/exp/lib/python3.9/site-packages (from valentine->pyjedai) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Preparing data for pyJedAI

# %%
num_of_entities = d1.shape[0]
d1.rename(columns={'Unnamed: 0': 'id'}, inplace=True)
print("Number of initial entities: ", num_of_entities)
# Out:
# Number of initial entities:  11139

# %% [markdown]
# # Data preview - Agroknow Incidents

# %%
d1
# Out:
#           id                 date  \
# 0          0  2022-07-30T00:00:00
# 1          1  2022-07-30T00:00:00
# 2          2  2022-07-29T00:00:00
# 3          3  2022-07-28T00:00:00
# 4          4  2022-07-28T00:00:00
# ...      ...                  ...
# 11134  11134  1994-05-05T00:00:00
# 11135  11135  1994-04-03T00:00:00
# 11136  11136  1994-03-28T00:00:00
# 11137  11137  1994-03-10T00:00:00
# 11138  11138  1994-01-07T00:00:00
#
#                                            originalTitle  \
# 0      Rachael’s Food Corporation Recalls Ready-To-Ea...
# 1      Conagra Brands, Inc., Recalls Frozen Beef Prod...
# 2      Lyons Magnus Voluntarily Recalls 53 Nutritiona...
# 3      Certain Groove Chocolate brand and Daniel Choc...
# 4      Danny’s Sub and Pizza Recalls Meat Pizza Produ...
# ...                                                  ...
# 11134                   Recall Notification: FSIS-017-94
# 11135                   Recall Notification: FSIS-009-94
# 11136                   Recall Notification: FSIS-014-94
# 11137                   Recall Notification: FSIS-033-94
# 11138                   Recall Notification: FSIS-024-94
#
#                                              description  \
# 0      024-2022\r\n\r\n  \r\n  High - Class I\r\n\r\n...
# 1      025-2022\r\n\r\n  \r\n  High - Class I\r\n\r\n...
# 2      FRESNO, Calif. – July 28, 2022 – Lyons Magnus ...
# 3      Food recall warning Certain Groove Chocolate b...
# 4      023-2022\r\n\r\n  \r\n  High - Class I\r\n\r\n...
# ...                                                  ...
# 11134  Case Number: 017-94   \n            Date Opene...
# 11135  Case Number: 009-94   \n            Date Opene...
# 11136  Case Number: 014-94   \r\n            Date Ope...
# 11137  Case Number: 033-94   \n            Date Opene...
# 11138  Case Number: 024-94   \r\n            Date Ope...
#
#                        product                                       hazard  \
# 0                        wraps                       listeria monocytogenes
# 1         frozen beef products                    eggs and products thereof
# 2      non-alcoholic beverages                        cronobacter sakazakii
# 3          dark chocolate bars                    milk and products thereof
# 4                        pizza  unauthorised use of federal inspection mark
# ...                        ...                                          ...
# 11134               ham slices                                 listeria spp
# 11135     frankfurter sausages                             plastic fragment
# 11136               ham slices                       listeria monocytogenes
# 11137                  sausage                                 listeria spp
# 11138           smoked sausage                       listeria monocytogenes
#
#                                     productCategory  hazardCategory  \
# 0                        prepared dishes and snacks      biological
# 1       meat and meat products (other than poultry)       allergens
# 2                           non-alcoholic beverages      biological
# 3      cocoa and cocoa preparations, coffee and tea       allergens
# 4                        prepared dishes and snacks           fraud
# ...                                             ...             ...
# 11134   meat and meat products (other than poultry)      biological
# 11135   meat and meat products (other than poultry)  foreign bodies
# 11136   meat and meat products (other than poultry)      biological
# 11137   meat and meat products (other than poultry)      biological
# 11138   meat and meat products (other than poultry)      biological
#
#                                         supplier  \
# 0                     Rachael’s Food Corporation
# 1                                 Conagra Brands
# 2                               Lyons Magnus LLC
# 3      Daniel Chocolates Groove Chocolate Inc.
# 4                          Danny’s Sub and Pizza
# ...                                          ...
# 11134                               KOEGEL MEATS
# 11135                          OSCAR MAYER FOODS
# 11136                           WILLOW FOODS INC
# 11137                     WIMMER'S MEAT PRODUCTS
# 11138              GERHARD'S NAPA VALLEY SAUSAGE
#
#                                                      url
# 0      https://www.fsis.usda.gov/recalls-alerts/racha...
# 1      https://www.fsis.usda.gov/recalls-alerts/conag...
# 2      https://www.fda.gov/safety/recalls-market-with...
# 3      https://recalls-rappels.canada.ca/en/alert-rec...
# 4      https://www.fsis.usda.gov/recalls-alerts/danny...
# ...                                                  ...
# 11134  https://www.fsis.usda.gov/wps/portal/fsis/topi...
# 11135  https://www.fsis.usda.gov/wps/portal/fsis/topi...
# 11136  https://www.fsis.usda.gov/wps/portal/fsis/topi...
# 11137  https://www.fsis.usda.gov/wps/portal/fsis/topi...
# 11138  https://www.fsis.usda.gov/wps/portal/fsis/topi...
#
# [11139 rows x 10 columns]

# %% [markdown]
# ## Keeps only Description

# %%
AK_processed = d1[['id', 'description']]
AK_processed
# Out:
#           id                                        description
# 0          0  024-2022\r\n\r\n  \r\n  High - Class I\r\n\r\n...
# 1          1  025-2022\r\n\r\n  \r\n  High - Class I\r\n\r\n...
# 2          2  FRESNO, Calif. – July 28, 2022 – Lyons Magnus ...
# 3          3  Food recall warning Certain Groove Chocolate b...
# 4          4  023-2022\r\n\r\n  \r\n  High - Class I\r\n\r\n...
# ...      ...                                                ...
# 11134  11134  Case Number: 017-94   \n            Date Opene...
# 11135  11135  Case Number: 009-94   \n            Date Opene...
# 11136  11136  Case Number: 014-94   \r\n            Date Ope...
# 11137  11137  Case Number: 033-94   \n            Date Opene...
# 11138  11138  Case Number: 024-94   \r\n            Date Ope...
#
# [11139 rows x 2 columns]

# %%
import re
def process_dataframe(df, column_name):
    # Make sure the column exists in the DataFrame
    if column_name not in df.columns:
        raise ValueError(f"Column {column_name} not found in DataFrame")

    # Define a function to clean each entry
    def clean_text(text):
        text = text.lower()  # Convert to lowercase
        text = re.sub(r'\\.', '', text)  # Remove backslashes and any character they escape
        text = re.sub(r'[\r\n]+', ' ', text)  # Replace \r and \n with a space
        return text

    # Apply the cleaning function to the specified column using .loc
    df.loc[:, column_name] = df[column_name].apply(clean_text)

    return df

AK_processed = d1[['id', 'description']]
AK_processed = process_dataframe(AK_processed, 'description')
AK_processed.head(5)
# Out:
#    id                                        description
# 0   0  024-2022      high - class i     product conta...
# 1   1  025-2022      high - class i     misbranding  ...
# 2   2  fresno, calif. – july 28, 2022 – lyons magnus ...
# 3   3  food recall warning certain groove chocolate b...
# 4   4  023-2022      high - class i     produced with...

# %% [markdown]
# # Number of exact duplicates

# %%
AK_processed = AK_processed.drop_duplicates(subset = ['description'])
print("Number of exact duplicates: ",  num_of_entities - AK_processed.shape[0])
# Out:
# Number of exact duplicates:  3546

# %% [markdown]
# # Data preview after dropping Exact Duplicates
# AK_processed

# %%
data = Data(dataset_1=AK_processed, id_column_name_1='id')
data.print_specs()
# Out:
# ***************************************************************************************************************************
#                                                    Data Report
# ***************************************************************************************************************************
# Type of Entity Resolution:  Dirty
# Dataset 1 (D1):
# 	Number of entities:  7593
# 	Number of NaN values:  0
# 	Memory usage [MB]:  24.44
# 	Attributes:
# 		 description
#
# Total number of entities:  7593
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# # Data preview without Exact duplicates

# %%
AK_processed
# Out:
#           id                                        description
# 0          0  024-2022      high - class i     product conta...
# 1          1  025-2022      high - class i     misbranding  ...
# 2          2  fresno, calif. – july 28, 2022 – lyons magnus ...
# 3          3  food recall warning certain groove chocolate b...
# 4          4  023-2022      high - class i     produced with...
# ...      ...                                                ...
# 11134  11134  case number: 017-94                date opened...
# 11135  11135  case number: 009-94                date opened...
# 11136  11136  case number: 014-94                date opened...
# 11137  11137  case number: 033-94                date opened...
# 11138  11138  case number: 024-94                date opened...
#
# [7593 rows x 2 columns]

# %%
# Check for duplicates using groupby
duplicates = AK_processed.groupby('description').size().reset_index(name='counts')
duplicates = duplicates[duplicates['counts'] > 1]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [description, counts]
# Index: []

# %% [markdown]
# # pyJedAI Applications on Data __without__ exact duplicates

# %% [markdown]
# # __Vector based blocking with Pytorch pre-trained embeddings__
# ---

# %% [markdown]
# Filtering step uses the same Filtering approach as before (i.e., ANN with k=10 and S-MiniLM) along with the reciprocity constraint for post-processing the original candidate pairs.

# %%
#@title  { vertical-output: true }
#@markdown 
#@markdown  ---

from pyjedai.clustering import ConnectedComponentsClustering, CenterClustering
from pyjedai.vector_based_blocking import EmbeddingsNNBlockBuilding

# -------------------------------------- #

LANGUAGE_MODEL = "sminilm"
TOPK = 10
CLUSTERING = ConnectedComponentsClustering
THRESHOLD = 0.95

# -------------------------------------- #



emb = EmbeddingsNNBlockBuilding(vectorizer=LANGUAGE_MODEL,
                                similarity_search='faiss')

blocks, g = emb.build_blocks(data,
                             top_k=TOPK,
                             similarity_distance='cosine',
                             load_embeddings_if_exist=False,
                             save_embeddings=True,
                             with_entity_matching=True)

emb.report()
# Out:
# Embeddings-NN Block Building [sminilm, faiss, cuda]:   0%|          | 0/7593 [00:00<?, ?it/s]
# Method name: Embeddings-NN Block Building
# Method info: Creates a set of candidate pais for every entity id based on Embeddings creariot and Similarity search among the vectors.
# Parameters:
# 	Vectorizer: sminilm
# 	Similarity-Search: faiss
# 	Top-K: 10
# 	Vector size: 384
#
# Runtime: 62.9475 seconds

# %% [markdown]
# ## Filtering Candidate Blocks
#
# Filtering blocks based on frequency. Keep candidates only if (A,B) and (B,A) exists.

# %%
def keep_unique_symmetric(d, keep_self=False):
    seen = set()
    result = {}

    for k, values in d.items():
        new_values = set()
        for v in values:
            if v in d and k in d[v]:  # check reciprocal
                pair = tuple(sorted((k, v)))
                if pair not in seen:
                    if k != v or keep_self:  # handle self-links
                        new_values.add(v)
                    seen.add(pair)
        if new_values:
            result[k] = new_values
    return result

new_blocks = keep_unique_symmetric(blocks)

# %% [markdown]
# ### Candidate pairs predicted with ANN S-mini-LM

# %%
nn_pairs_df = emb.export_to_df(new_blocks)

print("\n\nPredicted " , nn_pairs_df.shape[0], " matches.")

merged_df = pd.merge(nn_pairs_df.astype(str), AK_processed.astype(str), how='left', left_on='id1', right_on='id')
final_df = pd.merge(merged_df, AK_processed.astype(str), how='left', left_on='id2', right_on='id', suffixes=("_1", "_2"))
final_df.rename(columns={'id1': 'Predicted id1', 'id2': 'Predicted id2', 'id_1': 'Original id1', 'id_2': 'Original id2'}, inplace=True)
# Out:
# Predicted  12438  matches.

# %%
# @title Predicted Duplicates
final_df.drop(columns=['Predicted id1', 'Predicted id2'], inplace=True)
# from google.colab import files
final_df = final_df.replace('\n', '', regex=True)
final_df.to_csv("candidate_pairs_no_dups.csv", index=False)
# files.download('candidate_pairs_no_dups.csv')

# %%
final_df
# Out:
#       Predicted id1 Predicted id2 Original id1  \
# 0                 0          1705            0
# 1                 0           179            0
# 2                 0          1390            0
# 3              5135          8533         5135
# 4              5135          7212         5135
# ...             ...           ...          ...
# 12433         11123         11111        11123
# 12434         11111         11122        11111
# 12435         11096         11138        11096
# 12436         11138         11116        11138
# 12437         11105         11118        11105
#
#                                            description_1 Original id2  \
# 0      024-2022      high - class i     product conta...         1705
# 1      024-2022      high - class i     product conta...          179
# 2      024-2022      high - class i     product conta...         1390
# 3      washington, april 9, 2019 – great american mar...         8533
# 4      washington, april 9, 2019 – great american mar...         7212
# ...                                                  ...          ...
# 12433  case number: 021-95                date opened...        11111
# 12434  case number: 006-97  recall notification repor...        11122
# 12435  case number: 017-98  recall notification repor...        11138
# 12436  case number: 024-94                date opened...        11116
# 12437  case number: 014-97  recall notification repor...        11118
#
#                                            description_2
# 0      035-2021      high - class i     product conta...
# 1      018-2022      high - class i     product conta...
# 2      046-2021      high - class i     product conta...
# 3      washington, may 11, 2016 – ajinomoto windsor, ...
# 4      washington, june 9, 2017 – cc kitchens, llc, a...
# ...                                                  ...
# 12433  case number: 006-97  recall notification repor...
# 12434  case number: 026-95                date opened...
# 12435  case number: 024-94                date opened...
# 12436  case number: 003-95                date opened...
# 12437  case number: 041-95                date opened...
#
# [12438 rows x 6 columns]

# %% [markdown]
# # Matching with QWEN 2.5

# %% [markdown]
# The Verification step applies one of the latest and top-performing open-weight LLMs, namely Qwen2.5.

# %% [markdown]
# Make sure [Ollama](https://ollama.com/) exists and is runnning with `$ollama serve`

# %% [markdown]
# ### Initializing LLMS-Matching with QWEN 2.5

# %%
from pyjedai.llm_matching import OllamaMatching

llm_matcher = OllamaMatching('qwen2.5')
# Out:
# Pulling model qwen2.5 from ollama

# %% [markdown]
# Entity Matching Using a Few-Shot LLM Approach

# %%
pairs = llm_matcher.process(prediction=new_blocks, data=data, create_examples=True, suffix='tf')
# Out:
# Ollama Matching [Extracting Candidate Pairs]:   0%|          | 0/4681 [00:00<?, ?it/s]
# Embeddings-NN Block Building [sdistilroberta, faiss, cuda]:   0%|          | 0/7593 [00:00<?, ?it/s]
# Created ollama model qwen2.5-tf
# Ollama Matching [qwen2.5-tf]:   0%|          | 0/12438 [00:00<?, ?it/s]

# %%
print(f'Execution of matching with Qwen 2.5: {llm_matcher.execution_time}')
# Out:
# Execution of matching with Qwen 2.5: 7044.235345363617

# %% [markdown]
# # Predicted Pairs

# %%
nn_pairs_df = llm_matcher.export_to_df(pairs)


print("\n\nPredicted " , nn_pairs_df.shape[0], " matches.")

merged_df = pd.merge(nn_pairs_df.astype(str), AK_processed.astype(str), how='left', left_on='id1', right_on='id')
final_df = pd.merge(merged_df, AK_processed.astype(str), how='left', left_on='id2', right_on='id', suffixes=("_1", "_2"))
final_df.rename(columns={'id1': 'Predicted id1', 'id2': 'Predicted id2', 'id_1': 'Original id1', 'id_2': 'Original id2'}, inplace=True)
# Out:
# Predicted  701  matches.

# %%
# @title Predicted Duplicates
final_df.drop(columns=['Predicted id1', 'Predicted id2'], inplace=True)
# from google.colab import files
final_df = final_df.replace('\n', '', regex=True)
final_df.to_csv("candidate_pairs_no_dups_llms.csv", index=False)
# files.download('candidate_pairs_no_dups.csv')

final_df
# Out:
#     Original id1                                      description_1  \
# 0              0  024-2022      high - class i     product conta...
# 1              0  024-2022      high - class i     product conta...
# 2           4596  food recall warning - various cooked diced chi...
# 3           1060  food recall warning certain abbott brand powde...
# 4           1060  food recall warning certain abbott brand powde...
# ..           ...                                                ...
# 696         9784  pra no. 2014/14032 date published 25 mar 2014 ...
# 697        10317  page content green monkey ltd has recalled all...
# 698         9952  for immediate release -- cincinnati, ohio, mar...
# 699        10194  pra no. 2012/13225 date published 26 jul 2012 ...
# 700        10313  pra no. 2011/12971 date published 21 dec 2011 ...
#
#     Original id2                                      description_2
# 0           1705  035-2021      high - class i     product conta...
# 1            179  018-2022      high - class i     product conta...
# 2           4592  service interruption please note that due to r...
# 3            158  food recall warning certain abbott brand powde...
# 4           1065  abbott (nyse: abt) is initiating a proactive, ...
# ..           ...                                                ...
# 696         9785  manassen foods australia pty ltd has recalled ...
# 697        10314  pra no. 2011/12967 date published 20 dec 2011 ...
# 698        10573  for immediate release -- cincinnati, ohio, mar...
# 699        10196  page content simplot australia has recalled th...
# 700        10316  page content eko australia pty ltd has recalle...
#
# [701 rows x 4 columns]

# %% [markdown]
# # Clustering

# %%
import networkx as nx
from pyjedai.clustering import ConnectedComponentsClustering

graph = nx.Graph()

for pair in pairs:
    graph.add_edge(pair[0], pair[1], weight=1.0)

CLUSTERING = ConnectedComponentsClustering
THRESHOLD = 0.0

# -------------------------------------- #

ccc = CLUSTERING()
clusters = ccc.process(graph, data, similarity_threshold=THRESHOLD)
nn_pairs_df = ccc.export_to_df(clusters)


print("\n\nPredicted " , nn_pairs_df.shape[0], " matches.")

merged_df = pd.merge(nn_pairs_df.astype(str), AK_processed.astype(str), how='left', left_on='id1', right_on='id')
final_df = pd.merge(merged_df, AK_processed.astype(str), how='left', left_on='id2', right_on='id', suffixes=("_1", "_2"))
final_df.rename(columns={'id1': 'Predicted id1', 'id2': 'Predicted id2', 'id_1': 'Original id1', 'id_2': 'Original id2'}, inplace=True)
# Out:
# Predicted  1174  matches.

# %%
print("\n\nPredicted " , nn_pairs_df.shape[0], " matches.")
# Out:
# Predicted  1174  matches.

# %% [markdown]
# # Predicted Duplicates

# %%
# @title Predicted Duplicates
final_df.drop(columns=['Predicted id1', 'Predicted id2'], inplace=True)
# from google.colab import files
final_df = final_df.replace('\n', '', regex=True)
final_df.to_csv("candidate_pairs_no_dups_llms.csv", index=False)
# files.download('candidate_pairs_no_dups.csv')

# %%
final_df
# Out:
#      Original id1                                      description_1  \
# 0               0  024-2022      high - class i     product conta...
# 1               0  024-2022      high - class i     product conta...
# 2            1705  035-2021      high - class i     product conta...
# 3            4580  service interruption please note that due to r...
# 4            4580  service interruption please note that due to r...
# ...           ...                                                ...
# 1169         9784  pra no. 2014/14032 date published 25 mar 2014 ...
# 1170        10314  pra no. 2011/12967 date published 20 dec 2011 ...
# 1171         9952  for immediate release -- cincinnati, ohio, mar...
# 1172        10194  pra no. 2012/13225 date published 26 jul 2012 ...
# 1173        10313  pra no. 2011/12971 date published 21 dec 2011 ...
#
#      Original id2                                      description_2
# 0            1705  035-2021      high - class i     product conta...
# 1             179  018-2022      high - class i     product conta...
# 2             179  018-2022      high - class i     product conta...
# 3            1756  food recall warning - frozen all white meat fu...
# 4            4543  updated food recall warning - various gordon c...
# ...           ...                                                ...
# 1169         9785  manassen foods australia pty ltd has recalled ...
# 1170        10317  page content green monkey ltd has recalled all...
# 1171        10573  for immediate release -- cincinnati, ohio, mar...
# 1172        10196  page content simplot australia has recalled th...
# 1173        10316  page content eko australia pty ltd has recalle...
#
# [1174 rows x 4 columns]

# %%
print(f"Total Workflow execution time: {ccc.execution_time + llm_matcher.execution_time + emb.execution_time} sec.")
# Out:
# Total Workflow execution time: 7107.186249256134 sec.
